# %% [markdown]
# # Deep Learning - Melanoma Tumor Detection

# %% [markdown]
# ##### Source: https://www.kaggle.com/datasets/bhaveshmittal/melanoma-cancer-dataset?resource=download\n

# %% [markdown]
# ## Introduction

# %% [markdown]
# ### Why do we need this study?
#
#
# **Deep Learning** has emerged as a powerful tool in the field of **medical imaging** and has shown great potential in aiding the health community in the detection and diagnosis of **melanoma**. By leveraging deep learning algorithms, we can analyze medical images, such as **dermoscopy** or **biopsies**, with unprecedented accuracy and efficiency. Also, it can assist in the classification of melanoma into different subtypes. By training models on large datasets of labeled melanoma images, deep learning algorithms can learn to distinguish between various types of melanoma, such as basal cell melanoma, squamous cell melanoma, or malignant melanoma.
#
# Overall, deep learning has the potential to revolutionize melanoma detection and diagnosis. By leveraging the power of neural networks, we can enhance the accuracy, efficiency, and understanding of melanoma imaging, ultimately leading to improved patient care and outcomes in the field of dermatologic oncology.

# %% [markdown]
# ### Problem Statement
#
# The accurate detection and classification of **melanoma** play a crucial role in the diagnosis and treatment planning of patients. However, manual interpretation of medical images, such as dermoscopic scans, can be time-consuming and subjective, leading to potential errors and delays in patient care. Therefore, there is a need for an automated and reliable method to detect and classify melanoma from medical images.

# %% [markdown]
# ### Study Aim
#
# This study aims to develop a Convolutional Neural Network **(CNN)** using the **Keras** framework that can accurately detect and classify **Melanoma Tumors** from many curated images where every pixel holds the potential to redefine early detection. The CNN will be trained on a large dataset (13900 images) to learn the patterns and features associated with different skin types and also the views of melanoma's diverse manifestations.The study aims develop reliable models with high accuracy for melanoma classification.

# %% [markdown]
# ## Project Enviroment and Dataset Setup

# %% [markdown]
# ### Function to extracting the Dataset
# </div>
#
# This script sets up a project directory and extracts a dataset from the kaggle file and the extract_archive function extracts files from the archive zip into the dataset folder.
#
# Additionally, the script moves a portion of the files from the training set to the validation set to create a validation dataset. This ensures that the model's performance can be properly evaluated during training.
#
# The setup_project function encapsulates all these functionalities and sets up the project directory accordingly.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

import warnings
warnings.filterwarnings("ignore")

# %%
# %%time
#!pip install tqdm
#!pip install zipfile

import os
from zipfile import ZipFile
from tqdm import tqdm
from random import sample as rnd_sample
from shutil import move as move_file

def setup_project():
    print("Setting up project!!!")
    dir_files = os.listdir()

    #this extracts from archive zip the dataset
    def extract_archive():
        with ZipFile("/Users/riccardogurzu/Downloads/archive.zip", 'r') as zip_obj:
            file_list = zip_obj.namelist()
            with tqdm(total=len(file_list), desc="Extracting files") as pbar:
                for file in file_list:
                    zip_obj.extract(file, path="/Users/riccardogurzu/Downloads/dataset/")
                    pbar.update(1)

    if "dataset" not in dir_files:
        print("dataset folder not in project, creating it...")
        os.mkdir('dataset')

    if "archive.zip" not in dir_files:
        raise Exception("archive.zip IS NOT IN PROJECT, CANNOT SETUP IT UP")

    dataset_files = os.listdir("/Users/riccardogurzu/Downloads/dataset")

    if len(dataset_files) < 2:
        print("Extracting archive.zip!!!")
        extract_archive()

    def move_files_to_validation():
        paths = ['/Users/riccardogurzu/Downloads/dataset/train/Benign', '/Users/riccardogurzu/Downloads/dataset/train/Malignant']
        for path in paths:
            prefix = path.split('/')[-1]
            files = os.listdir('./dataset/train/' + prefix)
            n_files = int(len(files) * 0.2)
            for file in tqdm(rnd_sample(files, n_files), desc=f"Moving files to validation for {prefix}"):
                move_file(f"/Users/riccardogurzu/Downloads/dataset/train/{prefix}/{file}", f"/Users/riccardogurzu/Downloads/dataset/validation/{prefix}/{file}")

    if "validation" not in dataset_files:
        print("Creating validation folder...")
        os.mkdir('/Users/riccardogurzu/Downloads/dataset/validation')
        print("Creating validation/Benign folder...")
        os.mkdir('/Users/riccardogurzu/Downloads/dataset/validation/Benign')
        print("Creating validation/Malignant folder...")
        os.mkdir('/Users/riccardogurzu/Downloads/dataset/validation/Malignant')
        move_files_to_validation()

setup_project()
# Out:
# Setting up project!!!
# CPU times: user 3.12 ms, sys: 3.52 ms, total: 6.64 ms
# Wall time: 7.97 ms

# %% [markdown]
# ### Data preprocessing
# </div>
#
# Here we rescale the images with the rescale parameter set to 1/255, we normalize the pixel values of our images to fall within the range [0, 1], a common preprocessing step that aids in model convergence and stability.

# %%
# %%time
#!pip install tensorflow

train_dir = "/Users/riccardogurzu/Downloads/dataset/train/"
validation_dir = "/Users/riccardogurzu/Downloads/dataset/validation"
test_dir = "/Users/riccardogurzu/Downloads/dataset/test/"
target_size = (240, 240)
batch_size = 20
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.01 µs

# %%
# %%time
import time
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1./255)
validation_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size = target_size,
    batch_size = batch_size,
    class_mode='binary'
)

validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    target_size = target_size,
    batch_size = batch_size,
    class_mode='binary'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=target_size,
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False
)
# Out:
# Found 9504 images belonging to 2 classes.
# Found 2375 images belonging to 2 classes.
# Found 2000 images belonging to 2 classes.
# CPU times: user 102 ms, sys: 17.8 ms, total: 120 ms
# Wall time: 145 ms

# %% [markdown]
# The script displays the number of images found in each directory belonging to their respective classes: 9504 images for training and 2375 images for validation, divided in 2 classes, this being malignant and benign.

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Class images samples

# %%
assert train_generator.class_indices == validation_generator.class_indices

class_to_index_map = train_generator.class_indices
index_to_class_map = dict((v, k) for k, v in train_generator.class_indices.items())
print("class_to_index_map ->", class_to_index_map)
print("index_to_class_map ->", index_to_class_map)
# Out:
# class_to_index_map -> {'Benign': 0, 'Malignant': 1}
# index_to_class_map -> {0: 'Benign', 1: 'Malignant'}

# %%
import matplotlib
matplotlib.rcParams.update({
    'font.family': 'serif',
    'text.usetex': True,
    'font.size': 15,
    'figure.figsize': (16,9), 
    'lines.linewidth': 0.8
    })
import matplotlib.pyplot as plt
import numpy as np

# Define the dictionary to store the images by class name
images_per_class = {'Benign': [], 'Malignant': []}

# Quantity of images per class
desired_count_per_class = 3

# Loop until the both class got the same number of images
while any(len(images) < desired_count_per_class for images in images_per_class.values()):
    imagens, labels = next(train_generator)
    for i, label in enumerate(labels):
        class_name = list(train_generator.class_indices.keys())[list(train_generator.class_indices.values()).index(label)]
        if len(images_per_class[class_name]) < desired_count_per_class:
            images_per_class[class_name].append(imagens[i])

# Plotting images
fig, axes = plt.subplots(nrows=2, ncols=3)
fig.suptitle('Class Images of Train Dataset', fontsize=20)

for row, class_name in enumerate(images_per_class.keys()):
    for col in range(desired_count_per_class):
        axes[row, col].imshow(images_per_class[class_name][col])
        axes[row, col].set_title(class_name)
        axes[row, col].axis('off')

plt.tight_layout()
plt.subplots_adjust(top=0.88)
plt.show()

# %% [markdown]
# ### Division by Class in Train set

# %%
import os
import matplotlib.pyplot as plt

# Finding the local of the train folders for each class
train_dirs = {class_name: os.path.join(train_dir, class_name) for class_name in train_generator.class_indices.keys()}

# Count the files for each class
image_counts = {class_name: len(os.listdir(path)) for class_name, path in train_dirs.items()}

# Class name and quantities
class_names = list(image_counts.keys())
counts = list(image_counts.values())

# Plotting bar graph
plt.figure()
plt.bar(class_names, counts, color=['blue', 'orange'])

plt.title('Train set Class')
plt.xlabel('Class')
plt.ylabel('Quantity of images', labelpad=15)
plt.show()

# %% [markdown]
# ##  Model building & fitting | Classifier

# %% [markdown]
# The initial model building was the benchmark of deep learning slides classes, we decide to use the "standard" model to check the behavior of the the neural network with this kind of images.

# %% [markdown]
# ### Set The Initial parameters
# </div>
#
# We also implement to the epoch_steps and Validation_steps the math operation to find the ideal number for this paramters

# %%
# %%time
# Define some paramenters for the model
import math

input_shape = (240, 240, 3)
epochs = 30
epoch_steps = int(math.ceil(train_generator.samples/batch_size - batch_size))
validation_steps = int(math.ceil(validation_generator.samples/batch_size - batch_size))
print(f"Epoch steps -> {epoch_steps} | Validation steps -> {validation_steps}")
# Out:
# Epoch steps -> 456 | Validation steps -> 99
# CPU times: user 30 µs, sys: 2 µs, total: 32 µs
# Wall time: 32.9 µs

# %% [markdown]
# ### Building The CNN Model
# </div>
#
# The first approch with this model was to create one non complex model to optmize the computational resource and check the behaviour of the model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# Example of building a neural netword
classifier = Sequential()

# Pooling and Convuluted layers
classifier.add(Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
classifier.add(MaxPooling2D(pool_size=(2, 2)))
classifier.add(Conv2D(64, (3, 3), activation='relu'))
classifier.add(MaxPooling2D(pool_size=(2, 2)))

# Adding a flattening layer to flatten our data
classifier.add(Flatten())

# Dense Layers
classifier.add(Dense(128, activation='relu'))
classifier.add(Dense(1, activation='sigmoid'))

classifier.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 238, 238, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 119, 119, 32)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 117, 117, 64)      18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 58, 58, 64)        0
#  g2D)
#
#  flatten (Flatten)           (None, 215296)            0
#
#  dense (Dense)               (None, 128)               27558016
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 27577537 (105.20 MB)
# Trainable params: 27577537 (105.20 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Config the Compile

# %%
# %%time
# Model Compilation
classifier.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
# Out:
# CPU times: user 6.49 ms, sys: 1.14 ms, total: 7.63 ms
# Wall time: 6.26 ms

# %% [markdown]
# ### Setup the GPU (If it is avaliable)
# </div>
#
# Since the training can be a bit slow, we can speed it up by allocation a part of the computation to the GPU instead of just CPU: https://samanemami.medium.com/how-to-enhance-training-speed-in-tensorflow-72d950f041bb

# %%
# Get the GPU memory fraction to allocate
gpu_memory_fraction = 0.8

# Create GPUOptions with the fraction of GPU memory to allocate
gpu_options = tf.compat.v1.GPUOptions(
    per_process_gpu_memory_fraction=gpu_memory_fraction
)

# Create a session with the GPUOptions
session = tf.compat.v1.Session(
    config=tf.compat.v1.ConfigProto(gpu_options=gpu_options)
)

# %% [markdown]
# ### Trainning The CNN Model

# %%
# %%time
history = classifier.fit(
    train_generator,
    steps_per_epoch = epoch_steps,
    epochs = epochs,
    validation_data = validation_generator,
    validation_ste
# 456/456 [==============================] - 191s 419ms/step - loss: 0.0419 - accuracy: 0.9845 - val_loss: 0.6895 - val_accuracy: 0.8621
# Epoch 21/30
# 456/456 [==============================] - 212s 465ms/step - loss: 0.0469 - accuracy: 0.9842 - val_loss: 0.7464 - val_accuracy: 0.8480
# Epoch 22/30
# 456/456 [==============================] - 207s 455ms/step - loss: 0.0508 - accuracy: 0.9855 - val_loss: 0.8308 - val_accuracy: 0.8510
# Epoch 23/30
# 456/456 [==============================] - 206s 453ms/step - loss: 0.0195 - accuracy: 0.9940 - val_loss: 1.0354 - val_accuracy: 0.8535
# Epoch 24/30
# 456/456 [==============================] - 215s 471ms/step - loss: 0.0477 - accuracy: 0.9847 - val_loss: 0.8276 - val_accuracy: 0.8616
# Epoch 25/30
# 456/456 [==============================] - 220s 482ms/step - loss: 0.0426 - accuracy: 0.9871 - val_loss: 1.0989 - val_accuracy: 0.8273
# Epoch 26/30
# 456/456 [==============================] - 218s 479ms/step - loss: 0.0639 - accuracy: 0.9813 - val_loss: 0.8896 - val_accuracy: 0.8601
# Epoch 27/30
# 456/456 [==============================] - 220s 482ms/step - loss: 0.0284 - accuracy: 0.9958 - val_loss: 1.0200 - val_accuracy: 0.8535
# Epoch 28/30
# 456/456 [==============================] - 224s 491ms/step - loss: 0.0126 - accuracy: 0.9958 - val_loss: 1.1792 - val_accuracy: 0.8626
# Epoch 29/30
# 456/456 [==============================] - 227s 498ms/step - loss: 0.0383 - accuracy: 0.9904 - val_loss: 1.1148 - val_accuracy: 0.8389
# Epoch 30/30
# 456/456 [==============================] - 237s 519ms/step - loss: 0.0483 - accuracy: 0.9864 - val_loss: 1.1507 - val_accuracy: 0.8510
# CPU times: user 9h 5min 24s, sys: 59min 8s, total: 10h 4min 33s
# Wall time: 1h 33min 13s

# %% [markdown]
# ### Model validation

# %%
# %%time
import matplotlib.pyplot as plt
import matplotlib

# Reset to default configuration
matplotlib.rcdefaults()


def plot_accuracy_loss_graph(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(1, len(acc) + 1)

    plt.figure(figsize=(16, 9))
    plt.plot(epochs, acc, 'bo-', color='red', label='Training accuracy')
    plt.plot(epochs, val_acc, 'b', label='Validation accuract')
    plt.title('Training & validation accuracy', fontsize=15)
    plt.legend()

    plt.figure(figsize=(16, 9))
    plt.plot(epochs, loss, 'bo', color='red', label='Training loss')
    plt.plot(epochs, val_loss, 'b', label='Validation loss')
    plt.title('Training & validation loss', fontsize=15)
    plt.legend()

    plt.show()

plot_accuracy_loss_graph(history)
# Out:
# CPU times: user 722 ms, sys: 12.8 ms, total: 735 ms
# Wall time: 261 ms

# %% [markdown]
# ### Accuracy | Results</b></p>
# </div>
#
# **Training Accuracy (red)**: The training accuracy starts around 0.7 and quickly rises, stabilizing around 0.9. This indicates that the model is learning and adjusting well to the training data.
#
# **Validation Accuracy (blue)**: The validation accuracy begins well below the training accuracy, which is normal in the initial training cycles, but it increases and reaches a level similar to the training after a few epochs.
# It appears to oscillate slightly, but remains relatively stable, which is a good sign that the model is generalizing well and not merely memorizing the training data.
#
# ### Loss | Results</b></p>
# </div>
#
# **Training Loss (red)**: The training loss starts high, peaking in the early stages, but quickly decreases and stabilizes close to zero, indicating that the model is getting better at predicting the correct labels in the training set.
#
# **Validation Loss (blue)**: The validation loss also starts high with a peak in the beginning and then decreases. However, unlike the accuracy, the validation loss seems to exhibit more variability and fluctuations. This may be a sign that the model is struggling to adapt to the validation data as well as the training data, although the overall trend of decreasing loss is maintained.
#
# ### Overall Results Analysis</b></p>
# </div>
#
# **Overfitting**: The model does not appear to suffer from significant overfitting, as the validation and training accuracy are quite close and the validation losses do not increase over time.
#
# **Stability**: The model appears stable, as after the initial peak in the early epochs, the metrics tend to stabilize.
#
# **Initial Peaks**: The peaks in the training and validation loss in the first epoch are notable. This may be due to a poorly chosen initial set of weights, an initially too high learning rate, or simply the model quickly adjusting to the data.
#
# **Variations in Accuracy and Validation Loss**: The fluctuations in accuracy and validation loss suggest that the model may benefit from adjustments to the learning rate or the use of regularization methods, such as dropout or weight regularization, to help smooth out these fluctuations.

# %% [markdown]
# ##  Improvements and Adjustments previous Model | Classifier2</b>

# %% [markdown]
# Based in the first results from the initial model, we decided to implement the dropout in order to smooth out the small overfitting after 20 epochs, the main goal is the stability.
#
# The droupout will be setted in 0.5
#
# We also implement the callback to ensure the best version of the model, and setup it monitoring the accuracy with 5 patience iterations

# %%
import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout


# Define callbacks
callbacks_list = [
    keras.callbacks.EarlyStopping(
        monitor = "accuracy",
        patience = 5,
    ),
    keras.callbacks.ModelCheckpoint(
        filepath = "improved_model.keras",
        monitor = "val_loss",
        save_best_only = True,
    )
]


# Example of building a neural netword
classifier2 = Sequential()

# Pooling and Convuluted layers
classifier2.add(Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
classifier2.add(MaxPooling2D(pool_size=(2, 2)))
classifier2.add(Conv2D(64, (3, 3), activation='relu'))
classifier2.add(MaxPooling2D(pool_size=(2, 2)))

# Adding a flattening layer to flatten our data
classifier2.add(Flatten())

# Dense Layers and adding dropout
classifier2.add(Dense(128, activation='relu'))
classifier2.add(Dropout(0.5))
classifier2.add(Dense(1, activation='sigmoid'))

classifier2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 238, 238, 32)      896
#
#  max_pooling2d_2 (MaxPoolin  (None, 119, 119, 32)      0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 117, 117, 64)      18496
#
#  max_pooling2d_3 (MaxPoolin  (None, 58, 58, 64)        0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 215296)            0
#
#  dense_2 (Dense)             (None, 128)               27558016
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_3 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 27577537 (105.20 MB)
# Trainable params: 27577537 (105.20 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Config the Compile

# %%
# Model Compilation
classifier2.compile(
    optimizer='adam', 
    loss='binary_crossentropy', 
    metrics=['accuracy']
)

# %% [markdown]
# ### Trainning The CNN Model improved | Classifier2

# %%
# %%time
history2 = classifier2.fit(
    train_generator,
    steps_per_epoch = epoch_steps,
    epochs = epochs,
    callbacks = callbacks_list,
    validation_data = validation_generator,
    validation_steps = validation_steps
)
# Out:
# Epoch 1/30
# 456/456 [==============================] - 140s 307ms/step - loss: 0.1000 - accuracy: 0.9639 - val_loss: 0.5258 - val_accuracy: 0.8702
# Epoch 2/30
# 456/456 [==============================] - 146s 321ms/step - loss: 0.0952 - accuracy: 0.9663 - val_loss: 0.5190 - val_accuracy: 0.8793
# Epoch 3/30
# 456/456 [==============================] - 157s 345ms/step - loss: 0.0811 - accuracy: 0.9664 - val_loss: 0.4966 - val_accuracy: 0.8803
# Epoch 4/30
# Epoch 24/30
# 456/456 [==============================] - 223s 490ms/step - loss: 0.0405 - accuracy: 0.9867 - val_loss: 0.9690 - val_accuracy: 0.8732
# CPU times: user 8h 23min 9s, sys: 52min 32s, total: 9h 15min 41s
# Wall time: 1h 25min 30s

# %% [markdown]
# ### Model validation | Classifier2

# %%
# %%time
plot_accuracy_loss_graph(history2)
# Out:
# CPU times: user 1.16 s, sys: 19.7 ms, total: 1.18 s
# Wall time: 423 ms

# %% [markdown]
# As we can see, there's been a huge improvement resulting in a non-overfitting model that can actually be used.

# %% [markdown]
# ##  Model testing

# %% [markdown]
# With the model validated and improved, we can now fully test it against our test dataset and get a realistic measure of accuracy:

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model
import numpy as np

best_model = load_model("improved_model.keras")

#basically our preprocess flow right now...
def preprocess_image(img_path):
    img = image.load_img(img_path, target_size=target_size)
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    return img_array / 255.0  # rescale pixel values to [0,1]

# %% [markdown]
# We'll also shuffle the test files:

# %%
from random import shuffle

benign_test_files = ['./dataset/test/Benign/' + f for f in os.listdir('./dataset/test/Benign/')]
malignant_test_files = ['./dataset/test/Malignant/' + f for f in os.listdir('./dataset/test/Malignant/')]
all_test_files = benign_test_files + malignant_test_files
shuffle(all_test_files)
all_test_files
# Out:
# ['./dataset/test/Malignant/6370.jpg',
#  './dataset/test/Benign/6324.jpg',
#  './dataset/test/Benign/6974.jpg',
#  './dataset/test/Malignant/5602.jpg',
#  './dataset/test/Benign/6378.jpg',
#  './dataset/test/Malignant/6013.jpg',
#  './dataset/test/Benign/7243.jpg',
#  './dataset/test/Malignant/6148.jpg',
#  './dataset/test/Benign/6762.jpg',
#  './dataset/test/Benign/6871.jpg',
#  './dataset/test/Benign/6507.jpg',
#  './dataset/test/Malignant/6452.jpg',
#  './dataset/test/Malignant/5864.jpg',
#  './dataset/test/Malignant/5613.jpg',
#  './dataset/test/Malignant/6554.jpg',
#  './dataset/test/Malignant/5921.jpg',
#  './dataset/test/Malignant/6194.jpg',
#  './dataset/test/Benign/7236.jpg',
#  './dataset/test/Malignant/6155.jpg',
#  './dataset/test/Benign/7217.jpg',
#  './dataset/test/Malignant/5749.jpg',
#  './dataset/test/Malignant/6574.jpg',
#  './dataset/test/Benign/6952.jpg',
#  './dataset/test/Benign/6639.jpg',
#  './dataset/test/Benign/7068.jpg',
#  './dataset/test/Benign/7088.jpg',
#  './dataset/test/Benign/6504.jpg',
#  './dataset/test/Benign/6910.jpg',
#  './dataset/test/Benign/6721.jpg',
#  './dataset/test/Benign/6791.jpg',
#  './dataset/test/Benign/6371.jpg',
#  './dataset/test/Benign/6344.jpg',
#  './dataset/test/Benign/6815.jpg',
#  './dataset/test/Benign/6968.jpg',
#  './dataset/test/Malignant/5869.jpg',
#  './dataset/test/Benign/6410.jpg',
#  './dataset/test/Benign/6712.jpg',
#  './dataset/test/Benign/6348.jpg',
#  './dataset/test/Malignant/5878.jpg',
#  './dataset/test/Malignant/6170.jpg',
#  './dataset/test/Benign/6476.jpg',
#  './dataset/test/Malignant/6113.jpg',
#  './dataset/test/Benign/7069.jpg',
#  './dataset/test/Benign/7244.jpg',
#  './dataset/test/Benign/6607.jpg',
#  './dataset/test/Benign/7076.jpg',
#  './dataset/test/Malignant/5673.jpg',
#  './dataset/test/Benign/6946.jpg',
#  './dataset/test/Benign/7014.jpg',
#  './dataset/test/Benign/6490.jpg',
#  './dataset/test/Malignant/5609.jpg',
#  './dataset/test/Benign/6805.jpg',
#  './dataset/test/Benign/6495.jpg',
#  './dataset/test/Malignant/6151.jpg',
#  './dataset/test/Malignant/5745.jpg',
#  './dataset/test/Malignant/5954.jpg',
#  './dataset/test/Malignant/6119.jpg',
#  './dataset/test/Malignant/6031.jpg',
#  './dataset/test/Malignant/6329.jpg',
#  './dataset/test/Malignant/6550.jpg',
#  './dataset/test/Benign/6475.jpg',
#  './dataset/test/Benign/6929.jpg',
#  './dataset/test/Benign/6557.jpg',
#  './dataset/test/Malignant/6187.jpg',
#  './dataset/test/Malignant/5713.jpg',
#  './dataset/test/Benign/6993.jpg',
#  './dataset/test/Malignant/6005.jpg',
#  './dataset/test/Malignant/5646.jpg',
#  './dataset/test/Benign/7131.jpg',
#  './dataset/test/Benign/6483.jpg',
#  './dataset/test/Benign/6321.jpg',
#  './dataset/test/Malignant/5732.jpg',
#  './dataset/test/Malignant/6504.jpg',
#  './dataset/test/Malignant/6355.jpg',
#  './dataset/test/Malignant/5761.jpg',
#  './dataset/test/Benign/6588.jpg',
#  './dataset/test/Benign/7186.jpg',
#  './dataset/test/Benign/7162.jpg',
#  './dataset/test/Benign/6406.jpg',
#  './dataset/test/Benign/6356.jpg',
#  './dataset/test/Benign/6831.jpg',
#  './dataset/test/Benign/7192.jpg',
#  './dataset/test/Malignant/5636.jpg',
#  './dataset/test/Benign/6635.jpg',
#  './dataset/test/Benign/6426.jpg',
#  './dataset/test/Benign/7126.jpg',
#  './dataset/test/Benign/6788.jpg',
#  './dataset/test/Benign/6889.jpg',
#  './dataset/test/Malignant/5862.jpg',
#  './dataset/test/Benign/7020.jpg',
#  './dataset/test/Malignant/5957.jpg',
#  './dataset/test/Malignant/6014.jpg',
#  './dataset/test/Benign/6691.jpg',
#  './dataset/test/Benign/7092.jpg',
#  './dataset/test/Malignant/5835.jpg',
#  './dataset/test/Benign/6346.jpg',
#  './dataset/test/Benign/7185.jpg',
#  './dataset/test/Benign/6617.jpg',
#  './dataset/test/Malignant/6391.jpg',
#  './dataset/test/Malignant/6595.jpg',
#  './dataset/test/Malignant/5712.jpg',
#  './dataset/test/Malignant/5724.jpg',
#  './dataset/test/Benign/6565.jpg',
#  './dataset/test/Malignant/6259.jpg',
#  './dataset/test/Benign/7275.jpg',
#  './dataset/test/Benign/6522.jpg',
#  './dataset/test/Malignant/5642.jpg',
#  './dataset/test/Benign/6433.jpg',
#  './dataset/test/Benign/7066.jpg',
#  './dataset/test/Benign/7035.jpg',
#  './dataset/test/Malignant/6002.jpg',
#  './dataset/test/Benign/6463.jpg',
#  './dataset/test/Malignant/6025.jpg',
#  './dataset/test/Benign/6936.jpg',
#  './dataset/test/Malignant/5902.jpg',
#  './dataset/test/Malignant/5756.jpg',
#  './dataset/test/Malignant/5674.jpg',
#  './dataset/test/Benign/6935.jpg',
#  './dataset/test/Benign/6459.jpg',
#  './dataset/test/Benign/6673.jpg',
#  './dataset/test/Malignant/5808.jpg',
#  './dataset/test/Benign/6680.jpg',
#  './dataset/test/Malignant/5675.jpg',
#  './dataset/test/Malignant/6216.jpg',
#  './dataset/test/Benign/7148.jpg',
#  './dataset/test/Benign/7200.jpg',
#  './dataset/test/Benign/7221.jpg',
#  './dataset/test/Benign/6566.jpg',
#  './dataset/test/Malignant/5898.jpg',
#  './dataset/test/Malignant/6447.jpg',
#  './dataset/test/Benign/7161.jpg',
#  './dataset/test/Benign/6916.jpg',
#  './dataset/test/Benign/6461.jpg',
#  './dataset/test/Malignant/5881.jpg',
#  './dataset/test/Benign/6917.jpg',
#  './dataset/test/Benign/6977.jpg',
#  './dataset/test/Malignant/6367.jpg',
#  './dataset/test/Malignant/5607.jpg',
#  './dataset/test/Benign/7073.jpg',
#  './dataset/test/Benign/6920.jpg',
#  './dataset/test/Benign/7044.jpg',
#  './dataset/test/Malignant/6295.jpg',
#  './dataset/test/Malignant/6305.jpg',
#  './dataset/test/Benign/6542.jpg',
#  './dataset/test/Benign/6531.jpg',
#  './dataset/test/Benign/7091.jpg',
#  './dataset/test/Benign/6468.jpg',
#  './dataset/test/Benign/6611.jpg',
#  './dataset/test/Benign/6450.jpg',
#  './dataset/test/Malignant/5614.jpg',
#  './dataset/test/Benign/6440.jpg',
#  './dataset/test/Benign/7055.jpg',
#  './dataset/test/Malignant/6462.jpg',
#  './dataset/test/Benign/6842.jpg',
#  './dataset/test/Benign/6633.jpg',
#  './dataset/test/Malignant/5979.jpg',
#  './dataset/test/Benign/7242.jpg',
#  './dataset/test/Benign/7041.jpg',
#  './dataset/test/Malignant/6022.jpg',
#  './dataset/test/Benign/6616.jpg',
#  './dataset/test/Benign/7027.jpg',
#  './dataset/test/Malignant/5785.jpg',
#  './dataset/test/Malignant/6037.jpg',
#  './dataset/test/Benign/6370.jpg',
#  './dataset/test/Malignant/5653.jpg',
#  './dataset/test/Malignant/6066.jpg',
#  './dataset/test/Benign/6455.jpg',
#  './dataset/test/Malignant/5855.jpg',
#  './dataset/test/Benign/7183.jpg',
#  './dataset/test/Malignant/5858.jpg',
#  './dataset/test/Benign/6668.jpg',
#  './dataset/test/Malignant/6313.jpg',
#  './dataset/test/Malignant/6204.jpg',
#  './dataset/test/Malignant/5718.jpg',
#  './dataset/test/Malignant/6298.jpg',
#  './dataset/test/Benign/7284.jpg',
#  './dataset/test/Benign/6803.jpg',
#  './dataset/test/Malignant/5711.jpg',
#  './dataset/test/Malignant/6069.jpg',
#  './dataset/test/Malignant/5634.jpg',
#  './dataset/test/Benign/6844.jpg',
#  './dataset/test/Malignant/6095.jpg',
#  './dataset/test/Malignant/5824.jpg',
#  './dataset/test/Malignant/5809.jpg',
#  './dataset/test/Benign/6539.jpg',
#  './dataset/test/Benign/6601.jpg',
#  './dataset/test/Malignant/6373.jpg',
#  './dataset/test/Benign/7220.jpg',
#  './dataset/test/Malignant/6236.jpg',
#  './dataset/test/Benign/6724.jpg',
#  './dataset/test/Benign/6552.jpg',
#  './dataset/test/Malignant/6493.jpg',
#  './dataset/test/Benign/6953.jpg',
#  './dataset/test/Malignant/5766.jpg',
#  './dataset/test/Benign/6880.jpg',
#  './dataset/test/Benign/7229.jpg',
#  './dataset/test/Malignant/5649.jpg',
#  './dataset/test/Benign/6418.jpg',
#  './dataset/test/Malignant/6244.jpg',
#  './dataset/test/Malignant/6121.jpg',
#  './dataset/test/Benign/6500.jpg',
#  './dataset/test/Malignant/5866.jpg',
#  './dataset/test/Malignant/5603.jpg',
#  './dataset/test/Malignant/6327.jpg',
#  './dataset/test/Benign/6867.jpg',
#  './dataset/test/Benign/6363.jpg',
#  './dataset/test/Malignant/6009.jpg',
#  './dataset/test/Benign/6564.jpg',
#  './dataset/test/Malignant/5698.jpg',
#  './dataset/test/Benign/6409.jpg',
#  './dataset/test/Benign/6651.jpg',
#  './dataset/test/Malignant/5625.jpg',
#  './dataset/test/Malignant/5967.jpg',
#  './dataset/test/Benign/6383.jpg',
#  './dataset/test/Benign/6671.jpg',
#  './dataset/test/Malignant/6261.jpg',
#  './dataset/test/Benign/7176.jpg',
#  './dataset/test/Malignant/6286.jpg',
#  './dataset/test/Malignant/6135.jpg',
#  './dataset/test/Benign/6701.jpg',
#  ...]

# %% [markdown]
# Predicting images is now relatively easy and be achieved with the code below:

# %%
#simple method for predicting for test image
def predict_image(image_path):
    #preproccess it
    image_array = preprocess_image(image_path)
    result = best_model.predict(image_array, verbose = 0).flatten()
    #has to be single result...
    if result.shape[0] != 1:
        raise Exception(f'Error in predicting {image_path}')
    #base result is probability of being positive case...
    certainty = result[0]
    #parse it through a threshold
    predicted_class = 1 if certainty > 0.5 else 0
    #retrieve associated label
    predicted_class_label = index_to_class_map[predicted_class]
    #return all this info...
    return (certainty, predicted_class, predicted_class_label)

# %% [markdown]
# An example follows:

# %%
print("Testing file", all_test_files[3])
if all_test_files[3].split('/')[-2] == predict_image(all_test_files[3])[2]:
    print(f"Correctly predicted image as {all_test_files[3].split('/')[-2]}")
else:
    print(f"Incorrectly predicted image, did not predict as {all_test_files[3].split('/')[-2]}")
# Out:
# Testing file ./dataset/test/Malignant/5602.jpg
# Correctly predicted image as Malignant

# %% [markdown]
# We can see that it correctly predicted, the class. We now apply the same principle to the rest of the images:

# %%
correct_predictions = sum(predict_image(test_file)[2] == test_file.split('/')[-2] for test_file in tqdm(all_test_files, desc="Predicting test files"))
accuracy_rate = (correct_predictions / len(all_test_files)) * 100
print(f"Real accuracy rate: {accuracy_rate:.2f}%")
# Out:
# Predicting test files: 100%|██████████| 2000/2000 [01:04<00:00, 30.99it/s]
# Real accuracy rate: 90.70%

# %% [markdown]
# As we can see, we have very near validation results, of more than 90% accuracy! So our model is definitely appropriate for this task!
